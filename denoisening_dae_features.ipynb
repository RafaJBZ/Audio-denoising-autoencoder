# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaJBZ/Audio-denoising-autoencoder/blob/main/denoisening_dae_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Mar  1 23:24:06 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0              25W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
from tensorflow.keras.layers import Input, Dense, MaxPooling2D, Reshape, Conv2D, Flatten, Conv2DTranspose, UpSampling2D, Cropping2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import numpy as np
import tensorflow as tf
import os
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm

# %%
x_train = np.load('/content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/train/clean_hybrid_representations.npy')
x_train_noisy = np.load('/content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/train/noisy_hybrid_representations.npy')

# %%
x_train.shape, x_train_noisy.shape
# Out:
# ((36000, 148, 109), (36000, 148, 109))

# %%
x_train.shape[1:], x_train_noisy.shape[1:]
# Out:
# ((148, 109), (148, 109))

# %%
x_train = np.expand_dims(x_train, axis=-1)
x_train_noisy = np.expand_dims(x_train_noisy, axis=-1)
x_train.shape[1:], x_train_noisy.shape[1:]
# Out:
# ((148, 109, 1), (148, 109, 1))

# %%
def create_autoencoder(input_shape):
    input_layer = Input(shape=input_shape) # (148, 109, 1)

    x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_layer) # (148, 109, 32)
    x = MaxPooling2D((2, 2), padding='same')(x) # (74, 55, 32)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x) # (74, 55, 64)
    x = MaxPooling2D((2, 2), padding='same')(x) # (37, 28, 64)
    x = Flatten()(x) # (66304)

    latent_space = Dense(128, activation='relu')(x) # (128)

    x = Dense(37 * 28 * 64, activation='relu')(latent_space) # (37 * 28 * 64) = 66304
    x = Reshape((37, 28, 64))(x) # (37, 28, 64)
    x = Conv2DTranspose(64, (3, 3), activation='relu', padding='same')(x) # (37, 28, 64)
    x = UpSampling2D((2, 2))(x) # (74, 56, 64)
    x = Cropping2D(cropping=((0, 0), (0, 1)))(x) # (74, 55, 64)
    x = Conv2DTranspose(32, (3, 3), activation='relu', padding='same')(x) # (74, 55, 32)
    x = UpSampling2D((2, 2))(x) #  # (148, 110, 32)
    x = Cropping2D(cropping=((0, 0), (0, 1)))(x) # (148, 109, 32)
    output_layer = Conv2DTranspose(1, (3, 3), activation='sigmoid', padding='same')(x) # (148, 109, 1)

    autoencoder = Model(inputs=input_layer, outputs=output_layer)
    autoencoder.compile(optimizer='adam', loss='mean_squared_error')

    return autoencoder

# Create autoencoder model
input_shape = x_train.shape[1:]
autoencoder = create_autoencoder(input_shape)
print(autoencoder.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 148, 109, 1)]     0
#
#  conv2d (Conv2D)             (None, 148, 109, 32)      320
#
#  max_pooling2d (MaxPooling2  (None, 74, 55, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 74, 55, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 37, 28, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 66304)             0
#
#  dense (Dense)               (None, 128)               8487040
#
#  dense_1 (Dense)             (None, 66304)             8553216
#
#  reshape (Reshape)           (None, 37, 28, 64)        0
#
#  conv2d_transpose (Conv2DTr  (None, 37, 28, 64)        36928
#  anspose)
#
#  up_sampling2d (UpSampling2  (None, 74, 56, 64)        0
#  D)
#
#  cropping2d (Cropping2D)     (None, 74, 55, 64)        0
#
#  conv2d_transpose_1 (Conv2D  (None, 74, 55, 32)        18464
#  Transpose)
#
#  up_sampling2d_1 (UpSamplin  (None, 148, 110, 32)      0
#  g2D)
#
#  cropping2d_1 (Cropping2D)   (None, 148, 109, 32)      0
#
#  conv2d_transpose_2 (Conv2D  (None, 148, 109, 1)       289
#  Transpose)
#
# =================================================================
# Total params: 17114753 (65.29 MB)
# Trainable params: 17114753 (65.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=6,           # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore the best weights observed during training
)
# Define model checkpointing
checkpoint_path = "/content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras"
model_checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,   # Filepath to save the model
    monitor='val_loss',         # Monitor validation loss
    save_best_only=True,        # Save only the best model based on the monitored quantity
    verbose=1                   # Print messages about the saving process
)

# Train the autoencoder with early stopping and model checkpointing
history = autoencoder.fit(
    x_train_noisy,
    x_train,
    epochs=200,               # Increase the maximum number of epochs
    batch_size=32,
    validation_data=(x_train_noisy, x_train),
    callbacks=[early_stopping, model_checkpoint]  # Pass the EarlyStopping and ModelCheckpoint callbacks to the fit method
)
# Out:
# Epoch 1/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.4415
# Epoch 1: val_loss improved from inf to 1239.36292, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 34s 25ms/step - loss: 1239.4415 - val_loss: 1239.3629
# Epoch 2/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.9399
# Epoch 2: val_loss improved from 1239.36292 to 1239.33350, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.3477 - val_loss: 1239.3335
# Epoch 3/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.8677
# Epoch 3: val_loss improved from 1239.33350 to 1239.31689, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.3231 - val_loss: 1239.3169
# Epoch 4/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1237.1329
# Epoch 4: val_loss improved from 1239.31689 to 1239.31360, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.3131 - val_loss: 1239.3136
# Epoch 5/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.4326
# Epoch 5: val_loss improved from 1239.31360 to 1239.30188, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.3046 - val_loss: 1239.3019
# Epoch 6/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.3020
# Epoch 6: val_loss improved from 1239.30188 to 1239.29773, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.3020 - val_loss: 1239.2977
# Epoch 7/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2974
# Epoch 7: val_loss improved from 1239.29773 to 1239.29565, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2974 - val_loss: 1239.2957
# Epoch 8/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.8354
# Epoch 8: val_loss improved from 1239.29565 to 1239.29248, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2944 - val_loss: 1239.2925
# Epoch 9/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.9099
# Epoch 9: val_loss did not improve from 1239.29248
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2939 - val_loss: 1239.2954
# Epoch 10/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.8621
# Epoch 10: val_loss improved from 1239.29248 to 1239.28906, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2906 - val_loss: 1239.2891
# Epoch 11/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.0071
# Epoch 11: val_loss did not improve from 1239.28906
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2898 - val_loss: 1239.2914
# Epoch 12/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.6019
# Epoch 12: val_loss improved from 1239.28906 to 1239.28748, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2889 - val_loss: 1239.2875
# Epoch 13/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2874
# Epoch 13: val_loss improved from 1239.28748 to 1239.28662, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2874 - val_loss: 1239.2866
# Epoch 14/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.5156
# Epoch 14: val_loss improved from 1239.28662 to 1239.28503, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2865 - val_loss: 1239.2850
# Epoch 15/200
# 1123/1125 [============================>.] - ETA: 0s - loss: 1239.1996
# Epoch 15: val_loss improved from 1239.28503 to 1239.28479, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2855 - val_loss: 1239.2848
# Epoch 16/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.4414
# Epoch 16: val_loss improved from 1239.28479 to 1239.28296, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2841 - val_loss: 1239.2830
# Epoch 17/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.2126
# Epoch 17: val_loss improved from 1239.28296 to 1239.28247, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2839 - val_loss: 1239.2825
# Epoch 18/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2828
# Epoch 18: val_loss did not improve from 1239.28247
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2828 - val_loss: 1239.2827
# Epoch 19/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.4248
# Epoch 19: val_loss improved from 1239.28247 to 1239.28235, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2828 - val_loss: 1239.2823
# Epoch 20/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2815
# Epoch 20: val_loss improved from 1239.28235 to 1239.28186, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2815 - val_loss: 1239.2819
# Epoch 21/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2817
# Epoch 21: val_loss improved from 1239.28186 to 1239.28174, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2817 - val_loss: 1239.2817
# Epoch 22/200
# 1124/1125 [============================>.] - ETA: 0s - loss: 1238.5581
# Epoch 22: val_loss improved from 1239.28174 to 1239.28040, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2803 - val_loss: 1239.2804
# Epoch 23/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.5818
# Epoch 23: val_loss improved from 1239.28040 to 1239.27979, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2808 - val_loss: 1239.2798
# Epoch 24/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.2310
# Epoch 24: val_loss improved from 1239.27979 to 1239.27930, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2798 - val_loss: 1239.2793
# Epoch 25/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.1204
# Epoch 25: val_loss improved from 1239.27930 to 1239.27905, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2791 - val_loss: 1239.2791
# Epoch 26/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.7590
# Epoch 26: val_loss improved from 1239.27905 to 1239.27881, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2791 - val_loss: 1239.2788
# Epoch 27/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.9503
# Epoch 27: val_loss improved from 1239.27881 to 1239.27808, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2789 - val_loss: 1239.2781
# Epoch 28/200
# 1124/1125 [============================>.] - ETA: 0s - loss: 1238.7551
# Epoch 28: val_loss did not improve from 1239.27808
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2791 - val_loss: 1239.2797
# Epoch 29/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.1873
# Epoch 29: val_loss improved from 1239.27808 to 1239.27783, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2775 - val_loss: 1239.2778
# Epoch 30/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2771
# Epoch 30: val_loss improved from 1239.27783 to 1239.27747, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2771 - val_loss: 1239.2775
# Epoch 31/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.3220
# Epoch 31: val_loss improved from 1239.27747 to 1239.27686, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2780 - val_loss: 1239.2769
# Epoch 32/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2767
# Epoch 32: val_loss improved from 1239.27686 to 1239.27625, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2767 - val_loss: 1239.2762
# Epoch 33/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.7472
# Epoch 33: val_loss did not improve from 1239.27625
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2764 - val_loss: 1239.2772
# Epoch 34/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.6844
# Epoch 34: val_loss did not improve from 1239.27625
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2778 - val_loss: 1239.2811
# Epoch 35/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.2947
# Epoch 35: val_loss did not improve from 1239.27625
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2778 - val_loss: 1239.2924
# Epoch 36/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.8157
# Epoch 36: val_loss did not improve from 1239.27625
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2782 - val_loss: 1239.2762
# Epoch 37/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.1694
# Epoch 37: val_loss improved from 1239.27625 to 1239.27478, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2750 - val_loss: 1239.2748
# Epoch 38/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2782
# Epoch 38: val_loss did not improve from 1239.27478
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2782 - val_loss: 1239.2783
# Epoch 39/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.8154
# Epoch 39: val_loss did not improve from 1239.27478
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2773 - val_loss: 1239.2753
# Epoch 40/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1237.6429
# Epoch 40: val_loss improved from 1239.27478 to 1239.27417, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2749 - val_loss: 1239.2742
# Epoch 41/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1237.7267
# Epoch 41: val_loss did not improve from 1239.27417
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2754 - val_loss: 1239.2747
# Epoch 42/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.6333
# Epoch 42: val_loss improved from 1239.27417 to 1239.27380, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2753 - val_loss: 1239.2738
# Epoch 43/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1237.6570
# Epoch 43: val_loss improved from 1239.27380 to 1239.27356, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2745 - val_loss: 1239.2736
# Epoch 44/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.7179
# Epoch 44: val_loss did not improve from 1239.27356
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2747 - val_loss: 1239.2759
# Epoch 45/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2733
# Epoch 45: val_loss did not improve from 1239.27356
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2733 - val_loss: 1239.2736
# Epoch 46/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2753
# Epoch 46: val_loss did not improve from 1239.27356
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2753 - val_loss: 1239.2736
# Epoch 47/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.6835
# Epoch 47: val_loss did not improve from 1239.27356
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2733 - val_loss: 1239.2755
# Epoch 48/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.4662
# Epoch 48: val_loss improved from 1239.27356 to 1239.27332, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2738 - val_loss: 1239.2733
# Epoch 49/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.5981
# Epoch 49: val_loss improved from 1239.27332 to 1239.27185, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2737 - val_loss: 1239.2719
# Epoch 50/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.8011
# Epoch 50: val_loss did not improve from 1239.27185
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2732 - val_loss: 1239.2731
# Epoch 51/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.1198
# Epoch 51: val_loss improved from 1239.27185 to 1239.27148, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2720 - val_loss: 1239.2715
# Epoch 52/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.5151
# Epoch 52: val_loss improved from 1239.27148 to 1239.27124, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2731 - val_loss: 1239.2712
# Epoch 53/200
# 1124/1125 [============================>.] - ETA: 0s - loss: 1239.6072
# Epoch 53: val_loss did not improve from 1239.27124
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2733 - val_loss: 1239.2714
# Epoch 54/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2723
# Epoch 54: val_loss did not improve from 1239.27124
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2723 - val_loss: 1239.2714
# Epoch 55/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.4924
# Epoch 55: val_loss did not improve from 1239.27124
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2731 - val_loss: 1239.2754
# Epoch 56/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2716
# Epoch 56: val_loss improved from 1239.27124 to 1239.27051, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2716 - val_loss: 1239.2705
# Epoch 57/200
# 1122/1125 [============================>.] - ETA: 0s - loss: 1239.5413
# Epoch 57: val_loss did not improve from 1239.27051
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2719 - val_loss: 1239.2708
# Epoch 58/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.6528
# Epoch 58: val_loss did not improve from 1239.27051
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2726 - val_loss: 1239.2714
# Epoch 59/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.8029
# Epoch 59: val_loss did not improve from 1239.27051
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2722 - val_loss: 1239.2726
# Epoch 60/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.0986
# Epoch 60: val_loss improved from 1239.27051 to 1239.27026, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2717 - val_loss: 1239.2703
# Epoch 61/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.6461
# Epoch 61: val_loss did not improve from 1239.27026
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2733 - val_loss: 1239.2703
# Epoch 62/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.2477
# Epoch 62: val_loss improved from 1239.27026 to 1239.27014, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2712 - val_loss: 1239.2701
# Epoch 63/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.6075
# Epoch 63: val_loss did not improve from 1239.27014
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2712 - val_loss: 1239.2703
# Epoch 64/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.4122
# Epoch 64: val_loss improved from 1239.27014 to 1239.26978, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2716 - val_loss: 1239.2698
# Epoch 65/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.8055
# Epoch 65: val_loss improved from 1239.26978 to 1239.26917, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 16ms/step - loss: 1239.2711 - val_loss: 1239.2692
# Epoch 66/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2711
# Epoch 66: val_loss did not improve from 1239.26917
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2711 - val_loss: 1239.2694
# Epoch 67/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.0718
# Epoch 67: val_loss improved from 1239.26917 to 1239.26892, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2714 - val_loss: 1239.2689
# Epoch 68/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.2081
# Epoch 68: val_loss improved from 1239.26892 to 1239.26855, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2704 - val_loss: 1239.2686
# Epoch 69/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.6179
# Epoch 69: val_loss did not improve from 1239.26855
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2706 - val_loss: 1239.2686
# Epoch 70/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.0875
# Epoch 70: val_loss improved from 1239.26855 to 1239.26819, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2705 - val_loss: 1239.2682
# Epoch 71/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.4441
# Epoch 71: val_loss did not improve from 1239.26819
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2712 - val_loss: 1239.2792
# Epoch 72/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.9263
# Epoch 72: val_loss did not improve from 1239.26819
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2698 - val_loss: 1239.2682
# Epoch 73/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1237.4813
# Epoch 73: val_loss did not improve from 1239.26819
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2687 - val_loss: 1239.2692
# Epoch 74/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.9014
# Epoch 74: val_loss did not improve from 1239.26819
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2695 - val_loss: 1239.2695
# Epoch 75/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2709
# Epoch 75: val_loss did not improve from 1239.26819
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2709 - val_loss: 1239.2686
# Epoch 76/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.1898
# Epoch 76: val_loss improved from 1239.26819 to 1239.26782, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2703 - val_loss: 1239.2678
# Epoch 77/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.2656
# Epoch 77: val_loss improved from 1239.26782 to 1239.26758, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2704 - val_loss: 1239.2676
# Epoch 78/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1237.2333
# Epoch 78: val_loss did not improve from 1239.26758
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2690 - val_loss: 1239.2679
# Epoch 79/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.7760
# Epoch 79: val_loss improved from 1239.26758 to 1239.26746, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2693 - val_loss: 1239.2675
# Epoch 80/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.5059
# Epoch 80: val_loss did not improve from 1239.26746
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2704 - val_loss: 1239.2681
# Epoch 81/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.9330
# Epoch 81: val_loss improved from 1239.26746 to 1239.26709, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 16ms/step - loss: 1239.2692 - val_loss: 1239.2671
# Epoch 82/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.6674
# Epoch 82: val_loss improved from 1239.26709 to 1239.26672, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 16ms/step - loss: 1239.2692 - val_loss: 1239.2667
# Epoch 83/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.2603
# Epoch 83: val_loss did not improve from 1239.26672
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2686 - val_loss: 1239.2668
# Epoch 84/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1236.8763
# Epoch 84: val_loss did not improve from 1239.26672
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2694 - val_loss: 1239.2668
# Epoch 85/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.4542
# Epoch 85: val_loss did not improve from 1239.26672
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2692 - val_loss: 1239.2667
# Epoch 86/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2693
# Epoch 86: val_loss improved from 1239.26672 to 1239.26648, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2693 - val_loss: 1239.2665
# Epoch 87/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.0865
# Epoch 87: val_loss did not improve from 1239.26648
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2684 - val_loss: 1239.2679
# Epoch 88/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2683
# Epoch 88: val_loss improved from 1239.26648 to 1239.26624, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2683 - val_loss: 1239.2662
# Epoch 89/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.4988
# Epoch 89: val_loss did not improve from 1239.26624
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2683 - val_loss: 1239.2667
# Epoch 90/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.0022
# Epoch 90: val_loss did not improve from 1239.26624
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2673 - val_loss: 1239.2662
# Epoch 91/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.0897
# Epoch 91: val_loss did not improve from 1239.26624
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2683 - val_loss: 1239.2665
# Epoch 92/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2688
# Epoch 92: val_loss did not improve from 1239.26624
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2688 - val_loss: 1239.2667
# Epoch 93/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2688
# Epoch 93: val_loss improved from 1239.26624 to 1239.26587, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2688 - val_loss: 1239.2659
# Epoch 94/200
# 1122/1125 [============================>.] - ETA: 0s - loss: 1239.5106
# Epoch 94: val_loss did not improve from 1239.26587
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2679 - val_loss: 1239.2659
# Epoch 95/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2690
# Epoch 95: val_loss did not improve from 1239.26587
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2690 - val_loss: 1239.2659
# Epoch 96/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.0043
# Epoch 96: val_loss did not improve from 1239.26587
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2686 - val_loss: 1239.2667
# Epoch 97/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.9631
# Epoch 97: val_loss improved from 1239.26587 to 1239.26575, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2673 - val_loss: 1239.2657
# Epoch 98/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.3447
# Epoch 98: val_loss did not improve from 1239.26575
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2688 - val_loss: 1239.2689
# Epoch 99/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.5382
# Epoch 99: val_loss did not improve from 1239.26575
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2682 - val_loss: 1239.2661
# Epoch 100/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.9011
# Epoch 100: val_loss improved from 1239.26575 to 1239.26538, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2681 - val_loss: 1239.2654
# Epoch 101/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.0004
# Epoch 101: val_loss did not improve from 1239.26538
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2670 - val_loss: 1239.2654
# Epoch 102/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.1647
# Epoch 102: val_loss did not improve from 1239.26538
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2666 - val_loss: 1239.2656
# Epoch 103/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1237.7709
# Epoch 103: val_loss improved from 1239.26538 to 1239.26514, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2664 - val_loss: 1239.2651
# Epoch 104/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2701
# Epoch 104: val_loss did not improve from 1239.26514
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2701 - val_loss: 1239.2660
# Epoch 105/200
# 1124/1125 [============================>.] - ETA: 0s - loss: 1239.8191
# Epoch 105: val_loss improved from 1239.26514 to 1239.26501, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2684 - val_loss: 1239.2650
# Epoch 106/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.4927
# Epoch 106: val_loss did not improve from 1239.26501
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2668 - val_loss: 1239.2661
# Epoch 107/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2666
# Epoch 107: val_loss did not improve from 1239.26501
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2666 - val_loss: 1239.2660
# Epoch 108/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.2996
# Epoch 108: val_loss did not improve from 1239.26501
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2693 - val_loss: 1239.2659
# Epoch 109/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.2872
# Epoch 109: val_loss did not improve from 1239.26501
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2679 - val_loss: 1239.2653
# Epoch 110/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2670
# Epoch 110: val_loss did not improve from 1239.26501
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2670 - val_loss: 1239.2650
# Epoch 111/200
# 1124/1125 [============================>.] - ETA: 0s - loss: 1239.5397
# Epoch 111: val_loss improved from 1239.26501 to 1239.26489, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2667 - val_loss: 1239.2649
# Epoch 112/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2664
# Epoch 112: val_loss did not improve from 1239.26489
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2664 - val_loss: 1239.2649
# Epoch 113/200
# 1122/1125 [============================>.] - ETA: 0s - loss: 1239.1128
# Epoch 113: val_loss improved from 1239.26489 to 1239.26477, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2665 - val_loss: 1239.2648
# Epoch 114/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.9395
# Epoch 114: val_loss did not improve from 1239.26477
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2673 - val_loss: 1239.2655
# Epoch 115/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.4801
# Epoch 115: val_loss improved from 1239.26477 to 1239.26440, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2659 - val_loss: 1239.2644
# Epoch 116/200
# 1124/1125 [============================>.] - ETA: 0s - loss: 1239.4594
# Epoch 116: val_loss did not improve from 1239.26440
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2666 - val_loss: 1239.2645
# Epoch 117/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.3602
# Epoch 117: val_loss did not improve from 1239.26440
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2665 - val_loss: 1239.2648
# Epoch 118/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.9503
# Epoch 118: val_loss improved from 1239.26440 to 1239.26428, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2676 - val_loss: 1239.2643
# Epoch 119/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2656
# Epoch 119: val_loss improved from 1239.26428 to 1239.26404, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2656 - val_loss: 1239.2640
# Epoch 120/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2661
# Epoch 120: val_loss did not improve from 1239.26404
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2661 - val_loss: 1239.2643
# Epoch 121/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.4841
# Epoch 121: val_loss improved from 1239.26404 to 1239.26379, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2661 - val_loss: 1239.2638
# Epoch 122/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.0355
# Epoch 122: val_loss did not improve from 1239.26379
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2660 - val_loss: 1239.2638
# Epoch 123/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.5399
# Epoch 123: val_loss did not improve from 1239.26379
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2651 - val_loss: 1239.2642
# Epoch 124/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.3300
# Epoch 124: val_loss did not improve from 1239.26379
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2653 - val_loss: 1239.2643
# Epoch 125/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2667
# Epoch 125: val_loss improved from 1239.26379 to 1239.26355, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2667 - val_loss: 1239.2635
# Epoch 126/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.1132
# Epoch 126: val_loss did not improve from 1239.26355
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2655 - val_loss: 1239.2648
# Epoch 127/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1237.8777
# Epoch 127: val_loss improved from 1239.26355 to 1239.26331, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1239.2653 - val_loss: 1239.2633
# Epoch 128/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1239.2644
# Epoch 128: val_loss did not improve from 1239.26331
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2644 - val_loss: 1239.2643
# Epoch 129/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.6069
# Epoch 129: val_loss did not improve from 1239.26331
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2649 - val_loss: 1239.2639
# Epoch 130/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1237.4653
# Epoch 130: val_loss did not improve from 1239.26331
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2653 - val_loss: 1239.2639
# Epoch 131/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.8915
# Epoch 131: val_loss did not improve from 1239.26331
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2657 - val_loss: 1239.2640
# Epoch 132/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.8102
# Epoch 132: val_loss did not improve from 1239.26331
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2661 - val_loss: 1239.2640
# Epoch 133/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.9568
# Epoch 133: val_loss did not improve from 1239.26331
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1239.2665 - val_loss: 1239.2686
