# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaJBZ/Audio-denoising-autoencoder/blob/main/denoisening_dae_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Feb 28 21:46:08 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0              46W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
from tensorflow.keras.layers import Input, Dense, MaxPooling2D, Reshape, Conv2D, Flatten, Conv2DTranspose, UpSampling2D, Cropping2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import numpy as np
import tensorflow as tf
import os
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm

# %%
x_train = np.load('/content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/train/clean_hybrid_representations.npy')
x_train_noisy = np.load('/content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/train/noisy_hybrid_representations.npy')

# %%
x_train.shape, x_train_noisy.shape
# Out:
# ((36001, 148, 109), (36001, 148, 109))

# %%
x_train.shape[1:], x_train_noisy.shape[1:]
# Out:
# ((148, 109), (148, 109))

# %%
x_train = np.expand_dims(x_train, axis=-1)
x_train_noisy = np.expand_dims(x_train_noisy, axis=-1)
x_train.shape[1:], x_train_noisy.shape[1:]
# Out:
# ((148, 109, 1), (148, 109, 1))

# %%
def create_autoencoder(input_shape):
    input_layer = Input(shape=input_shape) # (148, 109, 1)

    x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_layer) # (148, 109, 32)
    x = MaxPooling2D((2, 2), padding='same')(x) # (74, 55, 32)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x) # (74, 55, 64)
    x = MaxPooling2D((2, 2), padding='same')(x) # (37, 28, 64)
    x = Flatten()(x) # (66304)

    latent_space = Dense(128, activation='relu')(x) # (128)

    x = Dense(37 * 28 * 64, activation='relu')(latent_space) # (37 * 28 * 64) = 66304
    x = Reshape((37, 28, 64))(x) # (37, 28, 64)
    x = Conv2DTranspose(64, (3, 3), activation='relu', padding='same')(x) # (37, 28, 64)
    x = UpSampling2D((2, 2))(x) # (74, 56, 64)
    x = Cropping2D(cropping=((0, 0), (0, 1)))(x) # (74, 55, 64)
    x = Conv2DTranspose(32, (3, 3), activation='relu', padding='same')(x) # (74, 55, 32)
    x = UpSampling2D((2, 2))(x) #  # (148, 110, 32)
    x = Cropping2D(cropping=((0, 0), (0, 1)))(x) # (148, 109, 32)
    output_layer = Conv2DTranspose(1, (3, 3), activation='sigmoid', padding='same')(x) # (148, 109, 1)

    autoencoder = Model(inputs=input_layer, outputs=output_layer)
    autoencoder.compile(optimizer='adam', loss='mean_squared_error')

    return autoencoder

# Create autoencoder model
input_shape = x_train.shape[1:]
autoencoder = create_autoencoder(input_shape)
print(autoencoder.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 148, 109, 1)]     0
#
#  conv2d (Conv2D)             (None, 148, 109, 32)      320
#
#  max_pooling2d (MaxPooling2  (None, 74, 55, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 74, 55, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 37, 28, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 66304)             0
#
#  dense (Dense)               (None, 128)               8487040
#
#  dense_1 (Dense)             (None, 66304)             8553216
#
#  reshape (Reshape)           (None, 37, 28, 64)        0
#
#  conv2d_transpose (Conv2DTr  (None, 37, 28, 64)        36928
#  anspose)
#
#  up_sampling2d (UpSampling2  (None, 74, 56, 64)        0
#  D)
#
#  cropping2d (Cropping2D)     (None, 74, 55, 64)        0
#
#  conv2d_transpose_1 (Conv2D  (None, 74, 55, 32)        18464
#  Transpose)
#
#  up_sampling2d_1 (UpSamplin  (None, 148, 110, 32)      0
#  g2D)
#
#  cropping2d_1 (Cropping2D)   (None, 148, 109, 32)      0
#
#  conv2d_transpose_2 (Conv2D  (None, 148, 109, 1)       289
#  Transpose)
#
# =================================================================
# Total params: 17114753 (65.29 MB)
# Trainable params: 17114753 (65.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=5,           # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore the best weights observed during training
)
# Define model checkpointing
checkpoint_path = "/content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras"
model_checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,   # Filepath to save the model
    monitor='val_loss',         # Monitor validation loss
    save_best_only=True,        # Save only the best model based on the monitored quantity
    verbose=1                   # Print messages about the saving process
)

# Train the autoencoder with early stopping and model checkpointing
history = autoencoder.fit(
    x_train_noisy,
    x_train,
    epochs=200,               # Increase the maximum number of epochs
    batch_size=32,
    validation_data=(x_train_noisy, x_train),
    callbacks=[early_stopping, model_checkpoint]  # Pass the EarlyStopping and ModelCheckpoint callbacks to the fit method
)
# Out:
# Epoch 1/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.4791
# Epoch 1: val_loss improved from inf to 1233.40088, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 30s 21ms/step - loss: 1233.4791 - val_loss: 1233.4009
# Epoch 2/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.3787
# Epoch 2: val_loss improved from 1233.40088 to 1233.36365, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3787 - val_loss: 1233.3636
# Epoch 3/200
# 1121/1126 [============================>.] - ETA: 0s - loss: 1232.5237
# Epoch 3: val_loss improved from 1233.36365 to 1233.34729, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3547 - val_loss: 1233.3473
# Epoch 4/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1233.7047
# Epoch 4: val_loss improved from 1233.34729 to 1233.33740, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3424 - val_loss: 1233.3374
# Epoch 5/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1232.0408
# Epoch 5: val_loss improved from 1233.33740 to 1233.33228, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3344 - val_loss: 1233.3323
# Epoch 6/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1234.0507
# Epoch 6: val_loss improved from 1233.33228 to 1233.32666, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3302 - val_loss: 1233.3267
# Epoch 7/200
# 1121/1126 [============================>.] - ETA: 0s - loss: 1232.2688
# Epoch 7: val_loss improved from 1233.32666 to 1233.32556, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3267 - val_loss: 1233.3256
# Epoch 8/200
# 1125/1126 [============================>.] - ETA: 0s - loss: 1233.3325
# Epoch 8: val_loss improved from 1233.32556 to 1233.32080, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3221 - val_loss: 1233.3208
# Epoch 9/200
# 1124/1126 [============================>.] - ETA: 0s - loss: 1233.5864
# Epoch 9: val_loss improved from 1233.32080 to 1233.31848, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3207 - val_loss: 1233.3185
# Epoch 10/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.3184
# Epoch 10: val_loss improved from 1233.31848 to 1233.31775, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3184 - val_loss: 1233.3177
# Epoch 11/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.3163
# Epoch 11: val_loss improved from 1233.31775 to 1233.31531, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3163 - val_loss: 1233.3153
# Epoch 12/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1232.4749
# Epoch 12: val_loss did not improve from 1233.31531
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.3154 - val_loss: 1233.3199
# Epoch 13/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1233.5809
# Epoch 13: val_loss improved from 1233.31531 to 1233.31348, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3147 - val_loss: 1233.3135
# Epoch 14/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.3131
# Epoch 14: val_loss improved from 1233.31348 to 1233.31226, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3131 - val_loss: 1233.3123
# Epoch 15/200
# 1124/1126 [============================>.] - ETA: 0s - loss: 1232.8619
# Epoch 15: val_loss did not improve from 1233.31226
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.3148 - val_loss: 1233.3124
# Epoch 16/200
# 1121/1126 [============================>.] - ETA: 0s - loss: 1234.7312
# Epoch 16: val_loss improved from 1233.31226 to 1233.31104, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3120 - val_loss: 1233.3110
# Epoch 17/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1233.6698
# Epoch 17: val_loss improved from 1233.31104 to 1233.31018, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3109 - val_loss: 1233.3102
# Epoch 18/200
# 1121/1126 [============================>.] - ETA: 0s - loss: 1233.9670
# Epoch 18: val_loss improved from 1233.31018 to 1233.30920, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3092 - val_loss: 1233.3092
# Epoch 19/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.3102
# Epoch 19: val_loss improved from 1233.30920 to 1233.30847, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3102 - val_loss: 1233.3085
# Epoch 20/200
# 1121/1126 [============================>.] - ETA: 0s - loss: 1233.1467
# Epoch 20: val_loss improved from 1233.30847 to 1233.30823, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3091 - val_loss: 1233.3082
# Epoch 21/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1233.3152
# Epoch 21: val_loss did not improve from 1233.30823
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.3085 - val_loss: 1233.3130
# Epoch 22/200
# 1121/1126 [============================>.] - ETA: 0s - loss: 1233.7256
# Epoch 22: val_loss improved from 1233.30823 to 1233.30664, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3071 - val_loss: 1233.3066
# Epoch 23/200
# 1125/1126 [============================>.] - ETA: 0s - loss: 1233.3082
# Epoch 23: val_loss improved from 1233.30664 to 1233.30640, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3073 - val_loss: 1233.3064
# Epoch 24/200
# 1125/1126 [============================>.] - ETA: 0s - loss: 1233.3381
# Epoch 24: val_loss improved from 1233.30640 to 1233.30530, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3059 - val_loss: 1233.3053
# Epoch 25/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1233.8101
# Epoch 25: val_loss did not improve from 1233.30530
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.3059 - val_loss: 1233.3059
# Epoch 26/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1234.2195
# Epoch 26: val_loss improved from 1233.30530 to 1233.30493, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3064 - val_loss: 1233.3049
# Epoch 27/200
# 1125/1126 [============================>.] - ETA: 0s - loss: 1233.3385
# Epoch 27: val_loss improved from 1233.30493 to 1233.30457, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3048 - val_loss: 1233.3046
# Epoch 28/200
# 1121/1126 [============================>.] - ETA: 0s - loss: 1233.6200
# Epoch 28: val_loss improved from 1233.30457 to 1233.30371, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3044 - val_loss: 1233.3037
# Epoch 29/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1233.4263
# Epoch 29: val_loss improved from 1233.30371 to 1233.30359, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3051 - val_loss: 1233.3036
# Epoch 30/200
# 1121/1126 [============================>.] - ETA: 0s - loss: 1233.6724
# Epoch 30: val_loss did not improve from 1233.30359
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.3040 - val_loss: 1233.3036
# Epoch 31/200
# 1125/1126 [============================>.] - ETA: 0s - loss: 1233.3376
# Epoch 31: val_loss improved from 1233.30359 to 1233.30334, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3058 - val_loss: 1233.3033
# Epoch 32/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1234.2794
# Epoch 32: val_loss did not improve from 1233.30334
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.3040 - val_loss: 1233.3037
# Epoch 33/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1234.3361
# Epoch 33: val_loss did not improve from 1233.30334
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.3032 - val_loss: 1233.3035
# Epoch 34/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1233.6444
# Epoch 34: val_loss improved from 1233.30334 to 1233.30249, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3047 - val_loss: 1233.3025
# Epoch 35/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1231.7228
# Epoch 35: val_loss did not improve from 1233.30249
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.3027 - val_loss: 1233.3040
# Epoch 36/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1233.9379
# Epoch 36: val_loss improved from 1233.30249 to 1233.30212, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3016 - val_loss: 1233.3021
# Epoch 37/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.3024
# Epoch 37: val_loss improved from 1233.30212 to 1233.30164, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3024 - val_loss: 1233.3016
# Epoch 38/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1233.7231
# Epoch 38: val_loss did not improve from 1233.30164
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.3010 - val_loss: 1233.3047
# Epoch 39/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1231.8749
# Epoch 39: val_loss improved from 1233.30164 to 1233.30139, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3022 - val_loss: 1233.3014
# Epoch 40/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.3018
# Epoch 40: val_loss did not improve from 1233.30139
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.3018 - val_loss: 1233.3022
# Epoch 41/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1232.8832
# Epoch 41: val_loss did not improve from 1233.30139
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.3038 - val_loss: 1233.3025
# Epoch 42/200
# 1121/1126 [============================>.] - ETA: 0s - loss: 1232.3063
# Epoch 42: val_loss improved from 1233.30139 to 1233.30090, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3007 - val_loss: 1233.3009
# Epoch 43/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1232.4565
# Epoch 43: val_loss improved from 1233.30090 to 1233.30017, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.2999 - val_loss: 1233.3002
# Epoch 44/200
# 1121/1126 [============================>.] - ETA: 0s - loss: 1233.9426
# Epoch 44: val_loss improved from 1233.30017 to 1233.29968, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3018 - val_loss: 1233.2997
# Epoch 45/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.3009
# Epoch 45: val_loss improved from 1233.29968 to 1233.29956, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3009 - val_loss: 1233.2996
# Epoch 46/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1233.7239
# Epoch 46: val_loss did not improve from 1233.29956
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.3015 - val_loss: 1233.3005
# Epoch 47/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1232.8490
# Epoch 47: val_loss did not improve from 1233.29956
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.3009 - val_loss: 1233.2999
# Epoch 48/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.3009
# Epoch 48: val_loss improved from 1233.29956 to 1233.29932, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.3009 - val_loss: 1233.2993
# Epoch 49/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.3003
# Epoch 49: val_loss did not improve from 1233.29932
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.3003 - val_loss: 1233.2993
# Epoch 50/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1233.8677
# Epoch 50: val_loss did not improve from 1233.29932
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2991 - val_loss: 1233.3010
# Epoch 51/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1233.1425
# Epoch 51: val_loss improved from 1233.29932 to 1233.29919, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.2998 - val_loss: 1233.2992
# Epoch 52/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1233.1779
# Epoch 52: val_loss improved from 1233.29919 to 1233.29834, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.2996 - val_loss: 1233.2983
# Epoch 53/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1233.4171
# Epoch 53: val_loss improved from 1233.29834 to 1233.29797, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.2997 - val_loss: 1233.2980
# Epoch 54/200
# 1125/1126 [============================>.] - ETA: 0s - loss: 1233.3185
# Epoch 54: val_loss improved from 1233.29797 to 1233.29773, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.2986 - val_loss: 1233.2977
# Epoch 55/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1232.4762
# Epoch 55: val_loss improved from 1233.29773 to 1233.29761, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.2979 - val_loss: 1233.2976
# Epoch 56/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1233.8075
# Epoch 56: val_loss did not improve from 1233.29761
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2996 - val_loss: 1233.2990
# Epoch 57/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.2996
# Epoch 57: val_loss did not improve from 1233.29761
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2996 - val_loss: 1233.2983
# Epoch 58/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1233.5228
# Epoch 58: val_loss did not improve from 1233.29761
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2985 - val_loss: 1233.2979
# Epoch 59/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1233.7767
# Epoch 59: val_loss did not improve from 1233.29761
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2993 - val_loss: 1233.2976
# Epoch 60/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1232.5925
# Epoch 60: val_loss improved from 1233.29761 to 1233.29700, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.2985 - val_loss: 1233.2970
# Epoch 61/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1233.2969
# Epoch 61: val_loss did not improve from 1233.29700
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2988 - val_loss: 1233.2976
# Epoch 62/200
# 1125/1126 [============================>.] - ETA: 0s - loss: 1233.3228
# Epoch 62: val_loss did not improve from 1233.29700
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2990 - val_loss: 1233.2970
# Epoch 63/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1233.2853
# Epoch 63: val_loss did not improve from 1233.29700
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2986 - val_loss: 1233.2970
# Epoch 64/200
# 1125/1126 [============================>.] - ETA: 0s - loss: 1233.3040
# Epoch 64: val_loss did not improve from 1233.29700
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2965 - val_loss: 1233.2970
# Epoch 65/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1232.5012
# Epoch 65: val_loss improved from 1233.29700 to 1233.29675, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.2975 - val_loss: 1233.2968
# Epoch 66/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1233.7338
# Epoch 66: val_loss did not improve from 1233.29675
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2993 - val_loss: 1233.2986
# Epoch 67/200
# 1121/1126 [============================>.] - ETA: 0s - loss: 1232.7438
# Epoch 67: val_loss improved from 1233.29675 to 1233.29614, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.2970 - val_loss: 1233.2961
# Epoch 68/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1233.4480
# Epoch 68: val_loss did not improve from 1233.29614
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2966 - val_loss: 1233.2971
# Epoch 69/200
# 1121/1126 [============================>.] - ETA: 0s - loss: 1232.9565
# Epoch 69: val_loss did not improve from 1233.29614
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2976 - val_loss: 1233.2963
# Epoch 70/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1234.6603
# Epoch 70: val_loss did not improve from 1233.29614
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2969 - val_loss: 1233.2966
# Epoch 71/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.2963
# Epoch 71: val_loss did not improve from 1233.29614
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2963 - val_loss: 1233.2970
# Epoch 72/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1232.8213
# Epoch 72: val_loss improved from 1233.29614 to 1233.29578, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.2974 - val_loss: 1233.2958
# Epoch 73/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1232.7264
# Epoch 73: val_loss improved from 1233.29578 to 1233.29553, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.2971 - val_loss: 1233.2955
# Epoch 74/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.2969
# Epoch 74: val_loss did not improve from 1233.29553
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2969 - val_loss: 1233.2961
# Epoch 75/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1232.6384
# Epoch 75: val_loss did not improve from 1233.29553
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2955 - val_loss: 1233.2960
# Epoch 76/200
# 1125/1126 [============================>.] - ETA: 0s - loss: 1233.3191
# Epoch 76: val_loss improved from 1233.29553 to 1233.29529, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.2972 - val_loss: 1233.2953
# Epoch 77/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1233.9403
# Epoch 77: val_loss did not improve from 1233.29529
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2959 - val_loss: 1233.2958
# Epoch 78/200
# 1121/1126 [============================>.] - ETA: 0s - loss: 1233.4961
# Epoch 78: val_loss did not improve from 1233.29529
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2959 - val_loss: 1233.2953
# Epoch 79/200
# 1120/1126 [============================>.] - ETA: 0s - loss: 1234.0623
# Epoch 79: val_loss did not improve from 1233.29529
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2965 - val_loss: 1233.2993
# Epoch 80/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1231.8955
# Epoch 80: val_loss improved from 1233.29529 to 1233.29480, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.2958 - val_loss: 1233.2948
# Epoch 81/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1233.1448
# Epoch 81: val_loss did not improve from 1233.29480
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2950 - val_loss: 1233.2960
# Epoch 82/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1234.0376
# Epoch 82: val_loss did not improve from 1233.29480
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2952 - val_loss: 1233.2950
# Epoch 83/200
# 1125/1126 [============================>.] - ETA: 0s - loss: 1233.3188
# Epoch 83: val_loss did not improve from 1233.29480
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2957 - val_loss: 1233.2948
# Epoch 84/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1233.2727
# Epoch 84: val_loss improved from 1233.29480 to 1233.29468, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.2969 - val_loss: 1233.2947
# Epoch 85/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1234.1951
# Epoch 85: val_loss did not improve from 1233.29468
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2953 - val_loss: 1233.2961
# Epoch 86/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1233.8180
# Epoch 86: val_loss did not improve from 1233.29468
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2955 - val_loss: 1233.2948
# Epoch 87/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1233.2380
# Epoch 87: val_loss did not improve from 1233.29468
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2953 - val_loss: 1233.2959
# Epoch 88/200
# 1121/1126 [============================>.] - ETA: 0s - loss: 1232.4126
# Epoch 88: val_loss did not improve from 1233.29468
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2950 - val_loss: 1233.2960
# Epoch 89/200
# 1122/1126 [============================>.] - ETA: 0s - loss: 1232.6273
# Epoch 89: val_loss improved from 1233.29468 to 1233.29456, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.2958 - val_loss: 1233.2946
# Epoch 90/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.2948
# Epoch 90: val_loss did not improve from 1233.29456
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2948 - val_loss: 1233.2946
# Epoch 91/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.2954
# Epoch 91: val_loss did not improve from 1233.29456
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2954 - val_loss: 1233.2948
# Epoch 92/200
# 1121/1126 [============================>.] - ETA: 0s - loss: 1232.4391
# Epoch 92: val_loss did not improve from 1233.29456
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2939 - val_loss: 1233.2949
# Epoch 93/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.2939
# Epoch 93: val_loss improved from 1233.29456 to 1233.29382, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/audio-denoising-variational-auto-encoder/data/noise_on_features/processed_data/autoencoder_model_features.keras
# 1126/1126 [==============================] - 16s 14ms/step - loss: 1233.2939 - val_loss: 1233.2938
# Epoch 94/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.2932
# Epoch 94: val_loss did not improve from 1233.29382
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2932 - val_loss: 1233.2938
# Epoch 95/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.2946
# Epoch 95: val_loss did not improve from 1233.29382
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2946 - val_loss: 1233.2939
# Epoch 96/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1233.2946
# Epoch 96: val_loss did not improve from 1233.29382
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2936 - val_loss: 1233.2947
# Epoch 97/200
# 1126/1126 [==============================] - ETA: 0s - loss: 1233.2953
# Epoch 97: val_loss did not improve from 1233.29382
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2953 - val_loss: 1233.2961
# Epoch 98/200
# 1123/1126 [============================>.] - ETA: 0s - loss: 1234.0681
# Epoch 98: val_loss did not improve from 1233.29382
# 1126/1126 [==============================] - 15s 13ms/step - loss: 1233.2949 - val_loss: 1233.2944
