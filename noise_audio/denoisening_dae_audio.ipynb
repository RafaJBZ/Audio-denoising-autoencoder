# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaJBZ/Audio-denoising-autoencoder/blob/main/denoisening_dae_audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Mar  1 06:51:12 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0              23W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
from tensorflow.keras.layers import Input, Dense, MaxPooling2D, Reshape, Conv2D, Flatten, Conv2DTranspose, UpSampling2D, Cropping2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import numpy as np
import tensorflow as tf
import os
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm

# %%
x_train = np.load('/content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/train/clean_hybrid_representations.npy')
x_train_noisy = np.load('/content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/train/noisy_hybrid_representations.npy')

# %%
x_train.shape, x_train_noisy.shape
# Out:
# ((36000, 148, 109), (36000, 148, 109))

# %%
x_train.shape[1:], x_train_noisy.shape[1:]
# Out:
# ((148, 109), (148, 109))

# %%
x_train = np.expand_dims(x_train, axis=-1)
x_train_noisy = np.expand_dims(x_train_noisy, axis=-1)
x_train.shape[1:], x_train_noisy.shape[1:]
# Out:
# ((148, 109, 1), (148, 109, 1))

# %%
def create_autoencoder(input_shape):
    input_layer = Input(shape=input_shape) # (148, 109, 1)

    x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_layer) # (148, 109, 32)
    x = MaxPooling2D((2, 2), padding='same')(x) # (74, 55, 32)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x) # (74, 55, 64)
    x = MaxPooling2D((2, 2), padding='same')(x) # (37, 28, 64)
    x = Flatten()(x) # (66304)

    latent_space = Dense(128, activation='relu')(x) # (128)

    x = Dense(37 * 28 * 64, activation='relu')(latent_space) # (37 * 28 * 64) = 66304
    x = Reshape((37, 28, 64))(x) # (37, 28, 64)
    x = Conv2DTranspose(64, (3, 3), activation='relu', padding='same')(x) # (37, 28, 64)
    x = UpSampling2D((2, 2))(x) # (74, 56, 64)
    x = Cropping2D(cropping=((0, 0), (0, 1)))(x) # (74, 55, 64)
    x = Conv2DTranspose(32, (3, 3), activation='relu', padding='same')(x) # (74, 55, 32)
    x = UpSampling2D((2, 2))(x) #  # (148, 110, 32)
    x = Cropping2D(cropping=((0, 0), (0, 1)))(x) # (148, 109, 32)
    output_layer = Conv2DTranspose(1, (3, 3), activation='sigmoid', padding='same')(x) # (148, 109, 1)

    autoencoder = Model(inputs=input_layer, outputs=output_layer)
    autoencoder.compile(optimizer='adam', loss='mean_squared_error')

    return autoencoder

# Create autoencoder model
input_shape = x_train.shape[1:]
autoencoder = create_autoencoder(input_shape)
print(autoencoder.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 148, 109, 1)]     0
#
#  conv2d (Conv2D)             (None, 148, 109, 32)      320
#
#  max_pooling2d (MaxPooling2  (None, 74, 55, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 74, 55, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 37, 28, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 66304)             0
#
#  dense (Dense)               (None, 128)               8487040
#
#  dense_1 (Dense)             (None, 66304)             8553216
#
#  reshape (Reshape)           (None, 37, 28, 64)        0
#
#  conv2d_transpose (Conv2DTr  (None, 37, 28, 64)        36928
#  anspose)
#
#  up_sampling2d (UpSampling2  (None, 74, 56, 64)        0
#  D)
#
#  cropping2d (Cropping2D)     (None, 74, 55, 64)        0
#
#  conv2d_transpose_1 (Conv2D  (None, 74, 55, 32)        18464
#  Transpose)
#
#  up_sampling2d_1 (UpSamplin  (None, 148, 110, 32)      0
#  g2D)
#
#  cropping2d_1 (Cropping2D)   (None, 148, 109, 32)      0
#
#  conv2d_transpose_2 (Conv2D  (None, 148, 109, 1)       289
#  Transpose)
#
# =================================================================
# Total params: 17114753 (65.29 MB)
# Trainable params: 17114753 (65.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=6,           # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore the best weights observed during training
)
# Define model checkpointing
checkpoint_path = "/content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras"
model_checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,   # Filepath to save the model
    monitor='val_loss',         # Monitor validation loss
    save_best_only=True,        # Save only the best model based on the monitored quantity
    verbose=1                   # Print messages about the saving process
)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=5, min_lr=0.001)

# Train the autoencoder with early stopping and model checkpointing
history = autoencoder.fit(
    x_train_noisy,
    x_train,
    epochs=200,               # Increase the maximum number of epochs
    batch_size=32,
    validation_data=(x_train_noisy, x_train),
    callbacks=[early_stopping, model_checkpoint, reduce_lr]  # Pass the EarlyStopping and ModelCheckpoint callbacks to the fit method
)
# Out:
# Epoch 1/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1242.0225
# Epoch 1: val_loss improved from inf to 1240.93262, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 49s 39ms/step - loss: 1241.0117 - val_loss: 1240.9326 - lr: 0.0010
# Epoch 2/200
# 1123/1125 [============================>.] - ETA: 0s - loss: 1240.6776
# Epoch 2: val_loss improved from 1240.93262 to 1240.89734, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.9114 - val_loss: 1240.8973 - lr: 0.0010
# Epoch 3/200
# 1124/1125 [============================>.] - ETA: 0s - loss: 1240.6840
# Epoch 3: val_loss improved from 1240.89734 to 1240.88147, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8906 - val_loss: 1240.8815 - lr: 0.0010
# Epoch 4/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.5361
# Epoch 4: val_loss improved from 1240.88147 to 1240.87000, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8761 - val_loss: 1240.8700 - lr: 0.0010
# Epoch 5/200
# 1122/1125 [============================>.] - ETA: 0s - loss: 1239.2358
# Epoch 5: val_loss improved from 1240.87000 to 1240.86230, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8685 - val_loss: 1240.8623 - lr: 0.0010
# Epoch 6/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.5419
# Epoch 6: val_loss improved from 1240.86230 to 1240.86011, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8652 - val_loss: 1240.8601 - lr: 0.0010
# Epoch 7/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.8381
# Epoch 7: val_loss improved from 1240.86011 to 1240.85596, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8591 - val_loss: 1240.8560 - lr: 0.0010
# Epoch 8/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.0514
# Epoch 8: val_loss did not improve from 1240.85596
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8568 - val_loss: 1240.8606 - lr: 0.0010
# Epoch 9/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.5743
# Epoch 9: val_loss improved from 1240.85596 to 1240.85486, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8561 - val_loss: 1240.8549 - lr: 0.0010
# Epoch 10/200
# 1122/1125 [============================>.] - ETA: 0s - loss: 1241.9932
# Epoch 10: val_loss improved from 1240.85486 to 1240.85083, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8535 - val_loss: 1240.8508 - lr: 0.0010
# Epoch 11/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.2655
# Epoch 11: val_loss improved from 1240.85083 to 1240.85010, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8510 - val_loss: 1240.8501 - lr: 0.0010
# Epoch 12/200
# 1124/1125 [============================>.] - ETA: 0s - loss: 1240.2131
# Epoch 12: val_loss improved from 1240.85010 to 1240.84790, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8505 - val_loss: 1240.8479 - lr: 0.0010
# Epoch 13/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1240.8481
# Epoch 13: val_loss improved from 1240.84790 to 1240.84692, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8481 - val_loss: 1240.8469 - lr: 0.0010
# Epoch 14/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1240.8485
# Epoch 14: val_loss improved from 1240.84692 to 1240.84644, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8485 - val_loss: 1240.8464 - lr: 0.0010
# Epoch 15/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1240.8484
# Epoch 15: val_loss improved from 1240.84644 to 1240.84558, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8484 - val_loss: 1240.8456 - lr: 0.0010
# Epoch 16/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.7378
# Epoch 16: val_loss improved from 1240.84558 to 1240.84399, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8473 - val_loss: 1240.8440 - lr: 0.0010
# Epoch 17/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.6436
# Epoch 17: val_loss did not improve from 1240.84399
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8452 - val_loss: 1240.8441 - lr: 0.0010
# Epoch 18/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1240.8478
# Epoch 18: val_loss did not improve from 1240.84399
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8478 - val_loss: 1240.8442 - lr: 0.0010
# Epoch 19/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.9222
# Epoch 19: val_loss did not improve from 1240.84399
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8472 - val_loss: 1240.8440 - lr: 0.0010
# Epoch 20/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.5450
# Epoch 20: val_loss improved from 1240.84399 to 1240.84216, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8440 - val_loss: 1240.8422 - lr: 0.0010
# Epoch 21/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.1951
# Epoch 21: val_loss did not improve from 1240.84216
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8444 - val_loss: 1240.8436 - lr: 0.0010
# Epoch 22/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.9291
# Epoch 22: val_loss improved from 1240.84216 to 1240.84180, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8434 - val_loss: 1240.8418 - lr: 0.0010
# Epoch 23/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.8726
# Epoch 23: val_loss improved from 1240.84180 to 1240.84094, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8438 - val_loss: 1240.8409 - lr: 0.0010
# Epoch 24/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.2859
# Epoch 24: val_loss improved from 1240.84094 to 1240.84082, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8430 - val_loss: 1240.8408 - lr: 0.0010
# Epoch 25/200
# 1123/1125 [============================>.] - ETA: 0s - loss: 1240.7910
# Epoch 25: val_loss improved from 1240.84082 to 1240.84033, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8429 - val_loss: 1240.8403 - lr: 0.0010
# Epoch 26/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1240.8409
# Epoch 26: val_loss did not improve from 1240.84033
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8409 - val_loss: 1240.8409 - lr: 0.0010
# Epoch 27/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.3705
# Epoch 27: val_loss improved from 1240.84033 to 1240.83936, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8420 - val_loss: 1240.8394 - lr: 0.0010
# Epoch 28/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.3524
# Epoch 28: val_loss did not improve from 1240.83936
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8413 - val_loss: 1240.8428 - lr: 0.0010
# Epoch 29/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.9479
# Epoch 29: val_loss improved from 1240.83936 to 1240.83838, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8390 - val_loss: 1240.8384 - lr: 0.0010
# Epoch 30/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.2637
# Epoch 30: val_loss did not improve from 1240.83838
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8409 - val_loss: 1240.8390 - lr: 0.0010
# Epoch 31/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.4017
# Epoch 31: val_loss improved from 1240.83838 to 1240.83813, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8403 - val_loss: 1240.8381 - lr: 0.0010
# Epoch 32/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.5726
# Epoch 32: val_loss improved from 1240.83813 to 1240.83777, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8385 - val_loss: 1240.8378 - lr: 0.0010
# Epoch 33/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.1443
# Epoch 33: val_loss did not improve from 1240.83777
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8387 - val_loss: 1240.8380 - lr: 0.0010
# Epoch 34/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.4833
# Epoch 34: val_loss improved from 1240.83777 to 1240.83716, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8392 - val_loss: 1240.8372 - lr: 0.0010
# Epoch 35/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.1885
# Epoch 35: val_loss did not improve from 1240.83716
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8373 - val_loss: 1240.8390 - lr: 0.0010
# Epoch 36/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1242.4388
# Epoch 36: val_loss improved from 1240.83716 to 1240.83655, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8385 - val_loss: 1240.8365 - lr: 0.0010
# Epoch 37/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.7832
# Epoch 37: val_loss did not improve from 1240.83655
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8385 - val_loss: 1240.8370 - lr: 0.0010
# Epoch 38/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.7986
# Epoch 38: val_loss did not improve from 1240.83655
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8370 - val_loss: 1240.8412 - lr: 0.0010
# Epoch 39/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.0192
# Epoch 39: val_loss improved from 1240.83655 to 1240.83582, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8384 - val_loss: 1240.8358 - lr: 0.0010
# Epoch 40/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.9680
# Epoch 40: val_loss did not improve from 1240.83582
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8373 - val_loss: 1240.8363 - lr: 0.0010
# Epoch 41/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.6893
# Epoch 41: val_loss did not improve from 1240.83582
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8367 - val_loss: 1240.8370 - lr: 0.0010
# Epoch 42/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.1998
# Epoch 42: val_loss improved from 1240.83582 to 1240.83545, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8361 - val_loss: 1240.8354 - lr: 0.0010
# Epoch 43/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.4589
# Epoch 43: val_loss did not improve from 1240.83545
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8367 - val_loss: 1240.8356 - lr: 0.0010
# Epoch 44/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.9707
# Epoch 44: val_loss improved from 1240.83545 to 1240.83496, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8374 - val_loss: 1240.8350 - lr: 0.0010
# Epoch 45/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.6113
# Epoch 45: val_loss did not improve from 1240.83496
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8359 - val_loss: 1240.8354 - lr: 0.0010
# Epoch 46/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.0985
# Epoch 46: val_loss improved from 1240.83496 to 1240.83472, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8357 - val_loss: 1240.8347 - lr: 0.0010
# Epoch 47/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.2751
# Epoch 47: val_loss improved from 1240.83472 to 1240.83459, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8344 - val_loss: 1240.8346 - lr: 0.0010
# Epoch 48/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.0868
# Epoch 48: val_loss did not improve from 1240.83459
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8361 - val_loss: 1240.8348 - lr: 0.0010
# Epoch 49/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.3153
# Epoch 49: val_loss improved from 1240.83459 to 1240.83423, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8353 - val_loss: 1240.8342 - lr: 0.0010
# Epoch 50/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.5061
# Epoch 50: val_loss did not improve from 1240.83423
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8339 - val_loss: 1240.8345 - lr: 0.0010
# Epoch 51/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.1958
# Epoch 51: val_loss did not improve from 1240.83423
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8335 - val_loss: 1240.8342 - lr: 0.0010
# Epoch 52/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.8787
# Epoch 52: val_loss improved from 1240.83423 to 1240.83398, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8344 - val_loss: 1240.8340 - lr: 0.0010
# Epoch 53/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.2255
# Epoch 53: val_loss improved from 1240.83398 to 1240.83362, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8342 - val_loss: 1240.8336 - lr: 0.0010
# Epoch 54/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.7297
# Epoch 54: val_loss improved from 1240.83362 to 1240.83350, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8342 - val_loss: 1240.8335 - lr: 0.0010
# Epoch 55/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1240.8346
# Epoch 55: val_loss improved from 1240.83350 to 1240.83337, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8346 - val_loss: 1240.8334 - lr: 0.0010
# Epoch 56/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.5934
# Epoch 56: val_loss did not improve from 1240.83337
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8336 - val_loss: 1240.8335 - lr: 0.0010
# Epoch 57/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.3452
# Epoch 57: val_loss improved from 1240.83337 to 1240.83289, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8333 - val_loss: 1240.8329 - lr: 0.0010
# Epoch 58/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.0497
# Epoch 58: val_loss did not improve from 1240.83289
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8337 - val_loss: 1240.8334 - lr: 0.0010
# Epoch 59/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.8331
# Epoch 59: val_loss did not improve from 1240.83289
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8324 - val_loss: 1240.8330 - lr: 0.0010
# Epoch 60/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.6283
# Epoch 60: val_loss did not improve from 1240.83289
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8323 - val_loss: 1240.8329 - lr: 0.0010
# Epoch 61/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.7999
# Epoch 61: val_loss did not improve from 1240.83289
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8318 - val_loss: 1240.8334 - lr: 0.0010
# Epoch 62/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.7631
# Epoch 62: val_loss did not improve from 1240.83289
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8322 - val_loss: 1240.8329 - lr: 0.0010
# Epoch 63/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.0275
# Epoch 63: val_loss improved from 1240.83289 to 1240.83228, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8323 - val_loss: 1240.8323 - lr: 0.0010
# Epoch 64/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1242.0786
# Epoch 64: val_loss did not improve from 1240.83228
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8334 - val_loss: 1240.8324 - lr: 0.0010
# Epoch 65/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.5487
# Epoch 65: val_loss did not improve from 1240.83228
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8319 - val_loss: 1240.8330 - lr: 0.0010
# Epoch 66/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.3392
# Epoch 66: val_loss improved from 1240.83228 to 1240.83203, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8324 - val_loss: 1240.8320 - lr: 0.0010
# Epoch 67/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.0850
# Epoch 67: val_loss improved from 1240.83203 to 1240.83142, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8323 - val_loss: 1240.8314 - lr: 0.0010
# Epoch 68/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.2120
# Epoch 68: val_loss did not improve from 1240.83142
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8322 - val_loss: 1240.8323 - lr: 0.0010
# Epoch 69/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.1914
# Epoch 69: val_loss did not improve from 1240.83142
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8309 - val_loss: 1240.8339 - lr: 0.0010
# Epoch 70/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.8451
# Epoch 70: val_loss improved from 1240.83142 to 1240.83105, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8323 - val_loss: 1240.8311 - lr: 0.0010
# Epoch 71/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.9087
# Epoch 71: val_loss did not improve from 1240.83105
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8315 - val_loss: 1240.8315 - lr: 0.0010
# Epoch 72/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.9497
# Epoch 72: val_loss did not improve from 1240.83105
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8318 - val_loss: 1240.8317 - lr: 0.0010
# Epoch 73/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.3411
# Epoch 73: val_loss did not improve from 1240.83105
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8311 - val_loss: 1240.8312 - lr: 0.0010
# Epoch 74/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.3995
# Epoch 74: val_loss did not improve from 1240.83105
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8300 - val_loss: 1240.8311 - lr: 0.0010
# Epoch 75/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.7891
# Epoch 75: val_loss improved from 1240.83105 to 1240.83044, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8320 - val_loss: 1240.8304 - lr: 0.0010
# Epoch 76/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1242.1740
# Epoch 76: val_loss did not improve from 1240.83044
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8314 - val_loss: 1240.8311 - lr: 0.0010
# Epoch 77/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.0487
# Epoch 77: val_loss did not improve from 1240.83044
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8311 - val_loss: 1240.8304 - lr: 0.0010
# Epoch 78/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.6385
# Epoch 78: val_loss did not improve from 1240.83044
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8306 - val_loss: 1240.8308 - lr: 0.0010
# Epoch 79/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.1278
# Epoch 79: val_loss did not improve from 1240.83044
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8298 - val_loss: 1240.8314 - lr: 0.0010
# Epoch 80/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.6455
# Epoch 80: val_loss improved from 1240.83044 to 1240.83032, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8308 - val_loss: 1240.8303 - lr: 0.0010
# Epoch 81/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.3820
# Epoch 81: val_loss improved from 1240.83032 to 1240.82983, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8296 - val_loss: 1240.8298 - lr: 0.0010
# Epoch 82/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.2831
# Epoch 82: val_loss improved from 1240.82983 to 1240.82971, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8302 - val_loss: 1240.8297 - lr: 0.0010
# Epoch 83/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.7509
# Epoch 83: val_loss improved from 1240.82971 to 1240.82935, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8311 - val_loss: 1240.8293 - lr: 0.0010
# Epoch 84/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1240.8315
# Epoch 84: val_loss did not improve from 1240.82935
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8315 - val_loss: 1240.8300 - lr: 0.0010
# Epoch 85/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.8412
# Epoch 85: val_loss did not improve from 1240.82935
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8302 - val_loss: 1240.8293 - lr: 0.0010
# Epoch 86/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.8900
# Epoch 86: val_loss did not improve from 1240.82935
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8331 - val_loss: 1240.8329 - lr: 0.0010
# Epoch 87/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.4203
# Epoch 87: val_loss did not improve from 1240.82935
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8289 - val_loss: 1240.8293 - lr: 0.0010
# Epoch 88/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.9325
# Epoch 88: val_loss did not improve from 1240.82935
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8303 - val_loss: 1240.8295 - lr: 0.0010
# Epoch 89/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.6948
# Epoch 89: val_loss improved from 1240.82935 to 1240.82898, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8307 - val_loss: 1240.8290 - lr: 0.0010
# Epoch 90/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.9199
# Epoch 90: val_loss improved from 1240.82898 to 1240.82874, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8292 - val_loss: 1240.8287 - lr: 0.0010
# Epoch 91/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.8405
# Epoch 91: val_loss did not improve from 1240.82874
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8311 - val_loss: 1240.8292 - lr: 0.0010
# Epoch 92/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1242.0842
# Epoch 92: val_loss did not improve from 1240.82874
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8303 - val_loss: 1240.8289 - lr: 0.0010
# Epoch 93/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1240.8292
# Epoch 93: val_loss improved from 1240.82874 to 1240.82849, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8292 - val_loss: 1240.8285 - lr: 0.0010
# Epoch 94/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.7903
# Epoch 94: val_loss did not improve from 1240.82849
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8296 - val_loss: 1240.8286 - lr: 0.0010
# Epoch 95/200
# 1124/1125 [============================>.] - ETA: 0s - loss: 1241.3163
# Epoch 95: val_loss did not improve from 1240.82849
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8297 - val_loss: 1240.8286 - lr: 0.0010
# Epoch 96/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.4967
# Epoch 96: val_loss did not improve from 1240.82849
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8308 - val_loss: 1240.8286 - lr: 0.0010
# Epoch 97/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.6615
# Epoch 97: val_loss did not improve from 1240.82849
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8280 - val_loss: 1240.8286 - lr: 0.0010
# Epoch 98/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1240.8289
# Epoch 98: val_loss improved from 1240.82849 to 1240.82837, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8289 - val_loss: 1240.8284 - lr: 0.0010
# Epoch 99/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.5071
# Epoch 99: val_loss did not improve from 1240.82837
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8292 - val_loss: 1240.8290 - lr: 0.0010
# Epoch 100/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.8262
# Epoch 100: val_loss did not improve from 1240.82837
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8307 - val_loss: 1240.8290 - lr: 0.0010
# Epoch 101/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1240.8293
# Epoch 101: val_loss did not improve from 1240.82837
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8293 - val_loss: 1240.8286 - lr: 0.0010
# Epoch 102/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.6158
# Epoch 102: val_loss did not improve from 1240.82837
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8281 - val_loss: 1240.8291 - lr: 0.0010
# Epoch 103/200
# 1122/1125 [============================>.] - ETA: 0s - loss: 1240.3900
# Epoch 103: val_loss did not improve from 1240.82837
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8280 - val_loss: 1240.8286 - lr: 0.0010
# Epoch 104/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.8849
# Epoch 104: val_loss did not improve from 1240.82837
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8279 - val_loss: 1240.8285 - lr: 0.0010
# Epoch 105/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.1476
# Epoch 105: val_loss improved from 1240.82837 to 1240.82776, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8275 - val_loss: 1240.8278 - lr: 0.0010
# Epoch 106/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.5780
# Epoch 106: val_loss did not improve from 1240.82776
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8285 - val_loss: 1240.8280 - lr: 0.0010
# Epoch 107/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.2762
# Epoch 107: val_loss did not improve from 1240.82776
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8273 - val_loss: 1240.8281 - lr: 0.0010
# Epoch 108/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.9177
# Epoch 108: val_loss did not improve from 1240.82776
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8280 - val_loss: 1240.8280 - lr: 0.0010
# Epoch 109/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.6023
# Epoch 109: val_loss did not improve from 1240.82776
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8284 - val_loss: 1240.8279 - lr: 0.0010
# Epoch 110/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1238.2678
# Epoch 110: val_loss did not improve from 1240.82776
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8285 - val_loss: 1240.8278 - lr: 0.0010
# Epoch 111/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.8309
# Epoch 111: val_loss improved from 1240.82776 to 1240.82764, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8268 - val_loss: 1240.8276 - lr: 0.0010
# Epoch 112/200
# 1124/1125 [============================>.] - ETA: 0s - loss: 1240.3818
# Epoch 112: val_loss did not improve from 1240.82764
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8264 - val_loss: 1240.8280 - lr: 0.0010
# Epoch 113/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.2137
# Epoch 113: val_loss did not improve from 1240.82764
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8287 - val_loss: 1240.8276 - lr: 0.0010
# Epoch 114/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.8370
# Epoch 114: val_loss improved from 1240.82764 to 1240.82751, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8281 - val_loss: 1240.8275 - lr: 0.0010
# Epoch 115/200
# 1125/1125 [==============================] - ETA: 0s - loss: 1240.8273
# Epoch 115: val_loss did not improve from 1240.82751
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8273 - val_loss: 1240.8279 - lr: 0.0010
# Epoch 116/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.8419
# Epoch 116: val_loss did not improve from 1240.82751
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8276 - val_loss: 1240.8286 - lr: 0.0010
# Epoch 117/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1240.2621
# Epoch 117: val_loss did not improve from 1240.82751
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8286 - val_loss: 1240.8281 - lr: 0.0010
# Epoch 118/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.4523
# Epoch 118: val_loss did not improve from 1240.82751
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8278 - val_loss: 1240.8286 - lr: 0.0010
# Epoch 119/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.0767
# Epoch 119: val_loss improved from 1240.82751 to 1240.82703, saving model to /content/drive/MyDrive/ITESO/Eight Semester-Primavera 2024/Deep Learning/Audio-denoising-autoencoder/data/noise_on_audio/processed_data/autoencoder_model_audio.keras
# 1125/1125 [==============================] - 19s 17ms/step - loss: 1240.8279 - val_loss: 1240.8270 - lr: 0.0010
# Epoch 120/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.1527
# Epoch 120: val_loss did not improve from 1240.82703
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8264 - val_loss: 1240.8278 - lr: 0.0010
# Epoch 121/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.8490
# Epoch 121: val_loss did not improve from 1240.82703
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8285 - val_loss: 1240.8326 - lr: 0.0010
# Epoch 122/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.0735
# Epoch 122: val_loss did not improve from 1240.82703
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8291 - val_loss: 1240.8276 - lr: 0.0010
# Epoch 123/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.3866
# Epoch 123: val_loss did not improve from 1240.82703
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8262 - val_loss: 1240.8271 - lr: 0.0010
# Epoch 124/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1241.5232
# Epoch 124: val_loss did not improve from 1240.82703
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8265 - val_loss: 1240.8270 - lr: 0.0010
# Epoch 125/200
# 1121/1125 [============================>.] - ETA: 0s - loss: 1239.8988
# Epoch 125: val_loss did not improve from 1240.82703
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8264 - val_loss: 1240.8270 - lr: 0.0010
# Epoch 126/200
# 1124/1125 [============================>.] - ETA: 0s - loss: 1241.2819
# Epoch 126: val_loss did not improve from 1240.82703
# 1125/1125 [==============================] - 18s 16ms/step - loss: 1240.8271 - val_loss: 1240.8274 - lr: 0.0010
